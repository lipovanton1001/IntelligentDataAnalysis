# %%
import numpy as np
print(np.array([1, 2, 3]))
# Out:
# [1 2 3]

# %%
a = str(input("Your Name"))
print ("Hello "+a+"!")
# Out:
# Hello dsd!

# %%
import numpy as np
a = np.array(np.random.randint(1, 100, size=10))
print('Масив: '+ str(a)+".")
print("Середнє значення масиву: "+ str(np.mean(a))+".")
# Out:
# Масив: [33 24 64 16 84 23 61 38 14  6].
# Середнє значення масиву: 36.3.
